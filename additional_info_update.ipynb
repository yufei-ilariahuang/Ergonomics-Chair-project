# %%
import pandas as pd
import csv
df = pd.read_csv("topic_df6.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35240 entries, 0 to 35239
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0.2                35240 non-null  int64
#  1   Unnamed: 0.1                35240 non-null  int64
#  2   Unnamed: 0                  35240 non-null  int64
#  3   Review Date                 35240 non-null  object
#  4   rating                      5114 non-null   float64
#  5   Product                     21580 non-null  object
#  6   Review                      35239 non-null  object
#  7   country                     32117 non-null  object
#  8   Price                       19146 non-null  float64
#  9   pre_wordnet                 35190 non-null  object
#  10  rev_word_count              35240 non-null  int64
#  11  unique_word_count           35240 non-null  int64
#  12  Rate                        35240 non-null  object
#  13  rating_predict              35240 non-null  int64
#  14  word                        35240 non-null  object
#  15  n_adj                       35240 non-null  object
#  16  bigram                      35240 non-null  object
#  17  phrase_machine_with_stop    35240 non-null  object
#  18  Phrasemachine_after_remove  35240 non-null  object
# dtypes: float64(2), int64(6), object(11)
# memory usage: 5.1+ MB

# %%
df['rating_predict'].describe()
# Out:
# count    35240.000000
# mean         4.174773
# std          1.353039
# min          1.000000
# 25%          4.000000
# 50%          5.000000
# 75%          5.000000
# max          5.000000
# Name: rating_predict, dtype: float64

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming df is your DataFrame and 'rating_predict' is the column with ratings
# Example:
# df = pd.DataFrame({
#     'rating_predict': [your data here]
# })

# Plotting
fig = plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
ax = df["rating_predict"].value_counts().plot(kind="bar", color='#0F539B', title="Rating Distribution")
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.01, p.get_height() * 1.01))
plt.xticks(rotation=90)  # Rotates the x-axis labels for better readability
plt.show()

# %%
import pandas as pd

# List of row numbers to read (subtract 1 for zero-based indexing)
rows_to_read = [26701, 33449, 3499, 4324, 7757, 8362]

filtered_df = df.iloc[rows_to_read]

filtered_df
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 Review Date  rating  \
# 26701         26701         26701       26701  2021-11-30     2.0
# 33449         33450         33450       33450  2022-03-29     NaN
# 3499           3499          3499        3499  2021-06-22     NaN
# 4324           4324          4324        4324  2021-12-03     NaN
# 7757           7757          7757        7757  2023-04-09     NaN
# 8362           8362          8362        8362  2023-06-29     NaN
#
#                                       Product  \
# 26701                  hermanMillerSayl Chair
# 33449  HBADA E1 Ergonomic Chair With Footrest
# 3499                               B07BDFW1Y7
# 4324                               B07GNDDNMW
# 7757                               B083SN1J2T
# 8362                               B09X34NWP5
#
#                                                   Review        country  \
# 26701  Great for back supportMy back feels better but...            USA
# 33449  I'd give it 6-Stars if I could.I've used it ev...            NaN
# 3499   So far, okay So far this chair isn't exactly w...  United States
# 4324   Great chair except for the armrests Ergonomica...  United States
# 7757   Love this chair! This chair is so comfortable!...  United States
# 8362   Outstanding Office Chair! Chair arrived quickl...  United States
#
#         Price                                        pre_wordnet  \
# 26701  735.00  back supportmy back feel better comfy 2 month ...
# 33449  259.00  'd give 6-stars could.i used everyday year . '...
# 3499   229.99  far , okay far exactly expecting . love adjust...
# 4324   189.99  except armrest ergonomically seat-comfort wise...
# 7757   319.99  love ! comfortable ! love . afraid stain easil...
# 8362   249.50  outstanding office ! arrived quickly & easy as...
#
#        rev_word_count  unique_word_count  \
# 26701              18                 17
# 33449              52                 40
# 3499               63                 52
# 4324               80                 57
# 7757               55                 44
# 8362               32                 31
#
#                                                     Rate  rating_predict  \
# 26701  {'1': 0.023697723, '2': 0.08326283, '3': 0.315...               4
# 33449  {'1': 0.0023162672, '2': 0.003241651, '3': 0.0...               5
# 3499   {'1': 0.0054836352, '2': 0.08618959, '3': 0.88...               3
# 4324   {'1': 0.0031873544, '2': 0.015503041, '3': 0.1...               4
# 7757   {'1': 0.0008417711, '2': 0.0010957932, '3': 0....               5
# 8362   {'1': 0.00037580193, '2': 0.0002951269, '3': 0...               5
#
#                                                     word  \
# 26701  ['back', 'supportmy', 'back', 'feel', 'comfy',...
# 33449  ['give', '6-stars', 'could.i', 'use', 'everyda...
# 3499   ['okay', 'exactly', 'expect', 'love', 'adjusta...
# 4324   ['except', 'armrest', 'ergonomically', 'seat-c...
# 7757   ['love', 'comfortable', 'love', 'afraid', 'sta...
# 8362   ['outstanding', 'office', 'arrive', 'quickly',...
#
#                                                    n_adj  \
# 26701            ['supportmy', 'feel', 'comfy', 'month']
# 33449  ['6-stars', 'could.i', 'use', 'everyday', 'yea...
# 3499   ['adjustable', 'armrest', 'lumbar', 'support',...
# 4324   ['seat-comfort', 'wise', 'armrest', 'cupped/co...
# 7757   ['love', 'comfortable', 'love', 'afraid', 'rol...
# 8362   ['outstanding', 'office', 'arrive', 'easy', 'a...
#
#                                                   bigram  \
# 26701            ['supportmy', 'feel', 'comfy', 'month']
# 33449  ['6-stars', 'could.i', 'use', 'everyday', 'yea...
# 3499   ['adjustable', 'armrest', 'lumbar', 'support',...
# 4324   ['seat-comfort', 'wise', 'armrest', 'cupped/co...
# 7757   ['love', 'comfortable', 'love', 'afraid', 'rol...
# 8362   ['outstanding', 'office', 'arrive', 'easy', 'a...
#
#                                 phrase_machine_with_stop  \
# 26701   ['2 months', '2 months of use', 'months of use']
# 33449                                     ['best thing']
# 3499   ['adjustable armrests', 'lumbar support', 'hig...
# 4324   ['seat-comfort wise', 'horizontal angle', 'typ...
# 7757   ['rollerblade wheels', 'didn’t work', 'it’s pe...
# 8362   ['tall person', '.customer service', 'timely r...
#
#                               Phrasemachine_after_remove
# 26701                                ['2 months of use']
# 33449                                     ['best thing']
# 3499   ['lumbar support pillow', 'adjustable armrests...
# 4324   ['seat-comfort wise', 'horizontal angle', 'typ...
# 7757   ['rollerblade wheels', 'it’s perfect', 'didn’t...
# 8362   ['inquiries.highly recommend', '.customer serv...

# %%
columns_to_read = ['Review Date', 'country', 'rating_predict', 'Price', 'Review']

filter_df = filtered_df[columns_to_read]

# %%
filter_df.rename(columns={'rating_predict': 'Rate'}, inplace=True)
# Out:
# <ipython-input-25-ef19f087dc62>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df.rename(columns={'rating_predict': 'Rate'}, inplace=True)

# %%
filter_df
# Out:
#       Review Date        country  Rate   Price  \
# 26701  2021-11-30  United States     4  735.00
# 33449  2022-03-29  United States     5  259.00
# 3499   2021-06-22  United States     3  229.99
# 4324   2021-12-03  United States     4  189.99
# 7757   2023-04-09  United States     5  319.99
# 8362   2023-06-29  United States     5  249.50
#
#                                                   Review
# 26701  Great for back supportMy back feels better but...
# 33449  I'd give it 6-Stars if I could.I've used it ev...
# 3499   So far, okay So far this chair isn't exactly w...
# 4324   Great chair except for the armrests Ergonomica...
# 7757   Love this chair! This chair is so comfortable!...
# 8362   Outstanding Office Chair! Chair arrived quickl...

# %%
columns_to_read = ['Review Date', 'Review', 'pre_wordnet', 'word', 'rev_word_count']

filter_df = filtered_df[columns_to_read]

# %%
filter_df.rename(columns={'rev_word_count': 'Review word count'}, inplace=True)
filter_df.rename(columns={'pre_wordnet': 'Remove Stopword'}, inplace=True)
filter_df.rename(columns={'word': 'Unigram Word'}, inplace=True)
filter_df
# Out:
# <ipython-input-9-155e7f093b09>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df.rename(columns={'rev_word_count': 'Review word count'}, inplace=True)
# <ipython-input-9-155e7f093b09>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df.rename(columns={'pre_wordnet': 'Remove Stopword'}, inplace=True)
# <ipython-input-9-155e7f093b09>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df.rename(columns={'word': 'Unigram Word'}, inplace=True)
#       Review Date                                             Review  \
# 26701  2021-11-30  Great for back supportMy back feels better but...
# 33449  2022-03-29  I'd give it 6-Stars if I could.I've used it ev...
# 3499   2021-06-22  So far, okay So far this chair isn't exactly w...
# 4324   2021-12-03  Great chair except for the armrests Ergonomica...
# 7757   2023-04-09  Love this chair! This chair is so comfortable!...
# 8362   2023-06-29  Outstanding Office Chair! Chair arrived quickl...
#
#                                          Remove Stopword  \
# 26701  back supportmy back feel better comfy 2 month ...
# 33449  'd give 6-stars could.i used everyday year . '...
# 3499   far , okay far exactly expecting . love adjust...
# 4324   except armrest ergonomically seat-comfort wise...
# 7757   love ! comfortable ! love . afraid stain easil...
# 8362   outstanding office ! arrived quickly & easy as...
#
#                                             Unigram Word  Review word count
# 26701  ['back', 'supportmy', 'back', 'feel', 'comfy',...                 18
# 33449  ['give', '6-stars', 'could.i', 'use', 'everyda...                 52
# 3499   ['okay', 'exactly', 'expect', 'love', 'adjusta...                 63
# 4324   ['except', 'armrest', 'ergonomically', 'seat-c...                 80
# 7757   ['love', 'comfortable', 'love', 'afraid', 'sta...                 55
# 8362   ['outstanding', 'office', 'arrive', 'quickly',...                 32

# %%
columns_to_read = ['Review Date', 'Review','n_adj']

filter_df = filtered_df[columns_to_read]

# %%
filter_df
# Out:
#       Review Date                                             Review  \
# 26701  2021-11-30  Great for back supportMy back feels better but...
# 33449  2022-03-29  I'd give it 6-Stars if I could.I've used it ev...
# 3499   2021-06-22  So far, okay So far this chair isn't exactly w...
# 4324   2021-12-03  Great chair except for the armrests Ergonomica...
# 7757   2023-04-09  Love this chair! This chair is so comfortable!...
# 8362   2023-06-29  Outstanding Office Chair! Chair arrived quickl...
#
#                                                    n_adj
# 26701            ['supportmy', 'feel', 'comfy', 'month']
# 33449  ['6-stars', 'could.i', 'use', 'everyday', 'yea...
# 3499   ['adjustable', 'armrest', 'lumbar', 'support',...
# 4324   ['seat-comfort', 'wise', 'armrest', 'cupped/co...
# 7757   ['love', 'comfortable', 'love', 'afraid', 'rol...
# 8362   ['outstanding', 'office', 'arrive', 'easy', 'a...

# %%
filter_df.rename(columns={'n_adj': 'After POS Tag'}, inplace=True)
# Out:
# <ipython-input-14-a9532cbd06db>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df.rename(columns={'n_adj': 'After POS Tag'}, inplace=True)

# %%
filter_df
# Out:
#       Review Date                                             Review  \
# 26701  2021-11-30  Great for back supportMy back feels better but...
# 33449  2022-03-29  I'd give it 6-Stars if I could.I've used it ev...
# 3499   2021-06-22  So far, okay So far this chair isn't exactly w...
# 4324   2021-12-03  Great chair except for the armrests Ergonomica...
# 7757   2023-04-09  Love this chair! This chair is so comfortable!...
# 8362   2023-06-29  Outstanding Office Chair! Chair arrived quickl...
#
#                                            After POS Tag
# 26701            ['supportmy', 'feel', 'comfy', 'month']
# 33449  ['6-stars', 'could.i', 'use', 'everyday', 'yea...
# 3499   ['adjustable', 'armrest', 'lumbar', 'support',...
# 4324   ['seat-comfort', 'wise', 'armrest', 'cupped/co...
# 7757   ['love', 'comfortable', 'love', 'afraid', 'rol...
# 8362   ['outstanding', 'office', 'arrive', 'easy', 'a...

# %%
df
# Out:
#        Unnamed: 0                                           Document  Topic  \
# 0               0  ['farce', 'lack', 'major', 'adjustment', 'abil...     -1
# 1               1  ['nice', 'problem', 'use', 'aeron', 'medium', ...     -1
# 2               2  ['correct', 'aeron', 'circulation', 'problem',...     -1
# 3               3  ['price', 'adjustable', 'annoy', 'flaw', 'unfo...      6
# 4               4  ['mixed', 'mix', 'feeling', 'star', 'agree', '...     -1
# ...           ...                                                ...    ...
# 35235       35235  ['adjustable', 'strap', 'dont', 'stay', 'posit...     -1
# 35236       35236                      ['true', 'pain', 'recommend']     -1
# 35237       35237  ['comfortable', 'front', 'little', 'unstable',...     -1
# 35238       35238  ['mean', 'high', 'brand', 'dxracer', 'much', '...     -1
# 35239       35239  ['hips', 'year', 'base', 'impractical', 'desig...     -1
#
#                                               Name  \
# 0               -1_support_comfortable_hour_lumbar
# 1               -1_support_comfortable_hour_lumbar
# 2               -1_support_comfortable_hour_lumbar
# 3      6_customer_service_customer_service_company
# 4               -1_support_comfortable_hour_lumbar
# ...                                            ...
# 35235           -1_support_comfortable_hour_lumbar
# 35236           -1_support_comfortable_hour_lumbar
# 35237           -1_support_comfortable_hour_lumbar
# 35238           -1_support_comfortable_hour_lumbar
# 35239           -1_support_comfortable_hour_lumbar
#
#                                           Representation  \
# 0      ['support', 'comfortable', 'hour', 'lumbar', '...
# 1      ['support', 'comfortable', 'hour', 'lumbar', '...
# 2      ['support', 'comfortable', 'hour', 'lumbar', '...
# 3      ['customer_service', 'customer', 'service', 'c...
# 4      ['support', 'comfortable', 'hour', 'lumbar', '...
# ...                                                  ...
# 35235  ['support', 'comfortable', 'hour', 'lumbar', '...
# 35236  ['support', 'comfortable', 'hour', 'lumbar', '...
# 35237  ['support', 'comfortable', 'hour', 'lumbar', '...
# 35238  ['support', 'comfortable', 'hour', 'lumbar', '...
# 35239  ['support', 'comfortable', 'hour', 'lumbar', '...
#
#                                      Representative_Docs  \
# 0      ["['uncomfortable', 'lumbar', 'support', 'hop'...
# 1      ["['uncomfortable', 'lumbar', 'support', 'hop'...
# 2      ["['uncomfortable', 'lumbar', 'support', 'hop'...
# 3      ["['customer_service', 'easy', 'assemble']", "...
# 4      ["['uncomfortable', 'lumbar', 'support', 'hop'...
# ...                                                  ...
# 35235  ["['uncomfortable', 'lumbar', 'support', 'hop'...
# 35236  ["['uncomfortable', 'lumbar', 'support', 'hop'...
# 35237  ["['uncomfortable', 'lumbar', 'support', 'hop'...
# 35238  ["['uncomfortable', 'lumbar', 'support', 'hop'...
# 35239  ["['uncomfortable', 'lumbar', 'support', 'hop'...
#
#                                              Top_n_words  Probability  \
# 0      support - comfortable - hour - lumbar - desk -...     0.000000
# 1      support - comfortable - hour - lumbar - desk -...     0.000000
# 2      support - comfortable - hour - lumbar - desk -...     0.000000
# 3      customer_service - customer - service - compan...     0.867056
# 4      support - comfortable - hour - lumbar - desk -...     0.000000
# ...                                                  ...          ...
# 35235  support - comfortable - hour - lumbar - desk -...     0.000000
# 35236  support - comfortable - hour - lumbar - desk -...     0.000000
# 35237  support - comfortable - hour - lumbar - desk -...     0.000000
# 35238  support - comfortable - hour - lumbar - desk -...     0.000000
# 35239  support - comfortable - hour - lumbar - desk -...     0.000000
#
#        Representative_document
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 35235                    False
# 35236                    False
# 35237                    False
# 35238                    False
# 35239                    False
#
# [35240 rows x 9 columns]

# %%
filtered_df = df[df['Topic'] == -1]
filtered_df
# Out:
#        Unnamed: 0                                           Document  Topic  \
# 0               0  ['farce', 'lack', 'major', 'adjustment', 'abil...     -1
# 1               1  ['nice', 'problem', 'use', 'aeron', 'medium', ...     -1
# 2               2  ['correct', 'aeron', 'circulation', 'problem',...     -1
# 4               4  ['mixed', 'mix', 'feeling', 'star', 'agree', '...     -1
# 5               5  ['serious', 'drawback', 'good:1', 'conform', '...     -1
# ...           ...                                                ...    ...
# 35235       35235  ['adjustable', 'strap', 'dont', 'stay', 'posit...     -1
# 35236       35236                      ['true', 'pain', 'recommend']     -1
# 35237       35237  ['comfortable', 'front', 'little', 'unstable',...     -1
# 35238       35238  ['mean', 'high', 'brand', 'dxracer', 'much', '...     -1
# 35239       35239  ['hips', 'year', 'base', 'impractical', 'desig...     -1
#
#                                      Name  \
# 0      -1_support_comfortable_hour_lumbar
# 1      -1_support_comfortable_hour_lumbar
# 2      -1_support_comfortable_hour_lumbar
# 4      -1_support_comfortable_hour_lumbar
# 5      -1_support_comfortable_hour_lumbar
# ...                                   ...
# 35235  -1_support_comfortable_hour_lumbar
# 35236  -1_support_comfortable_hour_lumbar
# 35237  -1_support_comfortable_hour_lumbar
# 35238  -1_support_comfortable_hour_lumbar
# 35239  -1_support_comfortable_hour_lumbar
#
#                                           Representation  \
# 0      ['support', 'comfortable', 'hour', 'lumbar', '...
# 1      ['support', 'comfortable', 'hour', 'lumbar', '...
# 2      ['support', 'comfortable', 'hour', 'lumbar', '...
# 4      ['support', 'comfortable', 'hour', 'lumbar', '...
# 5      ['support', 'comfortable', 'hour', 'lumbar', '...
# ...                                                  ...
# 35235  ['support', 'comfortable', 'hour', 'lumbar', '...
# 35236  ['support', 'comfortable', 'hour', 'lumbar', '...
# 35237  ['support', 'comfortable', 'hour', 'lumbar', '...
# 35238  ['support', 'comfortable', 'hour', 'lumbar', '...
# 35239  ['support', 'comfortable', 'hour', 'lumbar', '...
#
#                                      Representative_Docs  \
# 0      ["['uncomfortable', 'lumbar', 'support', 'hop'...
# 1      ["['uncomfortable', 'lumbar', 'support', 'hop'...
# 2      ["['uncomfortable', 'lumbar', 'support', 'hop'...
# 4      ["['uncomfortable', 'lumbar', 'support', 'hop'...
# 5      ["['uncomfortable', 'lumbar', 'support', 'hop'...
# ...                                                  ...
# 35235  ["['uncomfortable', 'lumbar', 'support', 'hop'...
# 35236  ["['uncomfortable', 'lumbar', 'support', 'hop'...
# 35237  ["['uncomfortable', 'lumbar', 'support', 'hop'...
# 35238  ["['uncomfortable', 'lumbar', 'support', 'hop'...
# 35239  ["['uncomfortable', 'lumbar', 'support', 'hop'...
#
#                                              Top_n_words  Probability  \
# 0      support - comfortable - hour - lumbar - desk -...          0.0
# 1      support - comfortable - hour - lumbar - desk -...          0.0
# 2      support - comfortable - hour - lumbar - desk -...          0.0
# 4      support - comfortable - hour - lumbar - desk -...          0.0
# 5      support - comfortable - hour - lumbar - desk -...          0.0
# ...                                                  ...          ...
# 35235  support - comfortable - hour - lumbar - desk -...          0.0
# 35236  support - comfortable - hour - lumbar - desk -...          0.0
# 35237  support - comfortable - hour - lumbar - desk -...          0.0
# 35238  support - comfortable - hour - lumbar - desk -...          0.0
# 35239  support - comfortable - hour - lumbar - desk -...          0.0
#
#        Representative_document
# 0                        False
# 1                        False
# 2                        False
# 4                        False
# 5                        False
# ...                        ...
# 35235                    False
# 35236                    False
# 35237                    False
# 35238                    False
# 35239                    False
#
# [16129 rows x 9 columns]

# %%
rows_to_read = [0, 214, 37, 7, 63, 100, 118, 3, 170, 212, 410, 606]

filtered_df = df.iloc[rows_to_read]

filtered_df.drop(columns=['Unnamed: 0', 'Document', 'Probability','Representative_document'], inplace=True)

filtered_df
# Out:
# <ipython-input-27-0968b36976fe>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.drop(columns=['Unnamed: 0', 'Document', 'Probability','Representative_document'], inplace=True)
#      Topic                                         Name  \
# 0       -1           -1_support_comfortable_hour_lumbar
# 214      0        0_comfortable_assemble_sturdy_stylish
# 37       1             1_lumbar_support_sit_comfortable
# 7        2             2_support_lumbar_adjustable_mesh
# 63       3             3_height_size_comfortable_petite
# 100      4                 4_wheel_caster_carpet_roller
# 118      5          5_home_comfortable_assemble_quality
# 3        6  6_customer_service_customer_service_company
# 170      7              7_quality_material_value_sturdy
# 212      8    8_adjustable_comfortable_armrest_assemble
# 410      9           9_cushion_pillow_head_rest_support
# 606     10       10_color_comfortable_blue_color_bright
#
#                                         Representation  \
# 0    ['support', 'comfortable', 'hour', 'lumbar', '...
# 214  ['comfortable', 'assemble', 'sturdy', 'stylish...
# 37   ['lumbar', 'support', 'sit', 'comfortable', 'b...
# 7    ['support', 'lumbar', 'adjustable', 'mesh', 'c...
# 63   ['height', 'size', 'comfortable', 'petite', 'l...
# 100  ['wheel', 'caster', 'carpet', 'roller', 'hardw...
# 118  ['home', 'comfortable', 'assemble', 'quality',...
# 3    ['customer_service', 'customer', 'service', 'c...
# 170  ['quality', 'material', 'value', 'sturdy', 'co...
# 212  ['adjustable', 'comfortable', 'armrest', 'asse...
# 410  ['cushion', 'pillow', 'head_rest', 'support', ...
# 606  ['color', 'comfortable', 'blue_color', 'bright...
#
#                                    Representative_Docs  \
# 0    ["['uncomfortable', 'lumbar', 'support', 'hop'...
# 214  ["['easy', 'assemble', 'comfortable']", "['lov...
# 37   ["['lumbar', 'support', 'lumbar', 'support', '...
# 7    ["['embody', 'investment', 'pro', 'disappear',...
# 63   ["['comfortable', 'tall', 'person', 'love']", ...
# 100  ["['price', 'assemble', 'perfect', 'short', 'f...
# 118  ["['home', 'office']", "['home', 'office']", "...
# 3    ["['customer_service', 'easy', 'assemble']", "...
# 170  ["['quality', 'price']", "['quality', 'price']...
# 212  ["['rest']", "['comfortable', 'love', 'rest', ...
# 410  ["['cushion']", "['cushion']", "['cushion', 'c...
# 606  ["['nice', 'color', 'comfortable', 'happy']", ...
#
#                                            Top_n_words
# 0    support - comfortable - hour - lumbar - desk -...
# 214  comfortable - assemble - sturdy - stylish - ad...
# 37   lumbar - support - sit - comfortable - back - ...
# 7    support - lumbar - adjustable - mesh - cushion...
# 63   height - size - comfortable - petite - leg - f...
# 100  wheel - caster - carpet - roller - hardwood_fl...
# 118  home - comfortable - assemble - quality - stur...
# 3    customer_service - customer - service - compan...
# 170  quality - material - value - sturdy - construc...
# 212  adjustable - comfortable - armrest - assemble ...
# 410  cushion - pillow - head_rest - support - comfo...
# 606  color - comfortable - blue_color - bright - de...

# %%
# Creating a list of names

Count = [16129, 4706, 1614, 1115, 800, 778, 735, 708, 656, 592, 583, 482]

# Creating the patient_name in the df data frame

filtered_df["Count"] = Count

# Observe the result

filtered_df.head()
# Out:
# <ipython-input-29-31f5bcd7cfce>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df["Count"] = Count
#      Topic                                   Name  \
# 0       -1     -1_support_comfortable_hour_lumbar
# 214      0  0_comfortable_assemble_sturdy_stylish
# 37       1       1_lumbar_support_sit_comfortable
# 7        2       2_support_lumbar_adjustable_mesh
# 63       3       3_height_size_comfortable_petite
#
#                                         Representation  \
# 0    ['support', 'comfortable', 'hour', 'lumbar', '...
# 214  ['comfortable', 'assemble', 'sturdy', 'stylish...
# 37   ['lumbar', 'support', 'sit', 'comfortable', 'b...
# 7    ['support', 'lumbar', 'adjustable', 'mesh', 'c...
# 63   ['height', 'size', 'comfortable', 'petite', 'l...
#
#                                    Representative_Docs  \
# 0    ["['uncomfortable', 'lumbar', 'support', 'hop'...
# 214  ["['easy', 'assemble', 'comfortable']", "['lov...
# 37   ["['lumbar', 'support', 'lumbar', 'support', '...
# 7    ["['embody', 'investment', 'pro', 'disappear',...
# 63   ["['comfortable', 'tall', 'person', 'love']", ...
#
#                                            Top_n_words  Count
# 0    support - comfortable - hour - lumbar - desk -...  16129
# 214  comfortable - assemble - sturdy - stylish - ad...   4706
# 37   lumbar - support - sit - comfortable - back - ...   1614
# 7    support - lumbar - adjustable - mesh - cushion...   1115
# 63   height - size - comfortable - petite - leg - f...    800

# %%
rows_to_read = [0, 214, 37, 7, 63, 100, 118, 3, 170, 212, 410, 606]

filtered_df = df.iloc[rows_to_read]

filtered_df.drop(columns=['Unnamed: 0', 'Document','Representative_document'], inplace=True)

filtered_df
# Out:
# <ipython-input-30-f2a7df2b006c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.drop(columns=['Unnamed: 0', 'Document','Representative_document'], inplace=True)
#      Topic                                         Name  \
# 0       -1           -1_support_comfortable_hour_lumbar
# 214      0        0_comfortable_assemble_sturdy_stylish
# 37       1             1_lumbar_support_sit_comfortable
# 7        2             2_support_lumbar_adjustable_mesh
# 63       3             3_height_size_comfortable_petite
# 100      4                 4_wheel_caster_carpet_roller
# 118      5          5_home_comfortable_assemble_quality
# 3        6  6_customer_service_customer_service_company
# 170      7              7_quality_material_value_sturdy
# 212      8    8_adjustable_comfortable_armrest_assemble
# 410      9           9_cushion_pillow_head_rest_support
# 606     10       10_color_comfortable_blue_color_bright
#
#                                         Representation  \
# 0    ['support', 'comfortable', 'hour', 'lumbar', '...
# 214  ['comfortable', 'assemble', 'sturdy', 'stylish...
# 37   ['lumbar', 'support', 'sit', 'comfortable', 'b...
# 7    ['support', 'lumbar', 'adjustable', 'mesh', 'c...
# 63   ['height', 'size', 'comfortable', 'petite', 'l...
# 100  ['wheel', 'caster', 'carpet', 'roller', 'hardw...
# 118  ['home', 'comfortable', 'assemble', 'quality',...
# 3    ['customer_service', 'customer', 'service', 'c...
# 170  ['quality', 'material', 'value', 'sturdy', 'co...
# 212  ['adjustable', 'comfortable', 'armrest', 'asse...
# 410  ['cushion', 'pillow', 'head_rest', 'support', ...
# 606  ['color', 'comfortable', 'blue_color', 'bright...
#
#                                    Representative_Docs  \
# 0    ["['uncomfortable', 'lumbar', 'support', 'hop'...
# 214  ["['easy', 'assemble', 'comfortable']", "['lov...
# 37   ["['lumbar', 'support', 'lumbar', 'support', '...
# 7    ["['embody', 'investment', 'pro', 'disappear',...
# 63   ["['comfortable', 'tall', 'person', 'love']", ...
# 100  ["['price', 'assemble', 'perfect', 'short', 'f...
# 118  ["['home', 'office']", "['home', 'office']", "...
# 3    ["['customer_service', 'easy', 'assemble']", "...
# 170  ["['quality', 'price']", "['quality', 'price']...
# 212  ["['rest']", "['comfortable', 'love', 'rest', ...
# 410  ["['cushion']", "['cushion']", "['cushion', 'c...
# 606  ["['nice', 'color', 'comfortable', 'happy']", ...
#
#                                            Top_n_words  Probability
# 0    support - comfortable - hour - lumbar - desk -...     0.000000
# 214  comfortable - assemble - sturdy - stylish - ad...     1.000000
# 37   lumbar - support - sit - comfortable - back - ...     0.977894
# 7    support - lumbar - adjustable - mesh - cushion...     1.000000
# 63   height - size - comfortable - petite - leg - f...     0.542785
# 100  wheel - caster - carpet - roller - hardwood_fl...     1.000000
# 118  home - comfortable - assemble - quality - stur...     0.737188
# 3    customer_service - customer - service - compan...     0.867056
# 170  quality - material - value - sturdy - construc...     1.000000
# 212  adjustable - comfortable - armrest - assemble ...     1.000000
# 410  cushion - pillow - head_rest - support - comfo...     0.982917
# 606  color - comfortable - blue_color - bright - de...     1.000000

# %%
dict = {"-1_support_comfortable_hour_lumbar": "Lumbar Support and Comfort Over Hours",
   "6_customer_service_customer_service_company": "Customer Service and Company Interaction",
   "2_support_lumbar_adjustable_mesh": "Adjustable Lumbar Support and Mesh Design",
   "16_cylinder_part_replacement_warranty": "Cylinder Parts and Replacement Warranty",
   "11_desk_height_assemble_table": "Assembly Ease and Desk Height Compatibility",
   "1_lumbar_support_sit_comfortable": "Lumbar Support Comfort",
   "22_comfortable_assemble_sturdy_ajustments": "Comfort, Sturdiness, and Adjustment Ease",
   "9_cushion_pillow_head_rest_support": "Cushioning and Headrest Support",
   "3_height_size_comfortable_petite": "Comfort for Petite Sizes and Height Adjustment",
   "32_mesh_breathable_material_fabric": "Breathable Mesh Material",
   "30_sale_range_value_dollar": "Sale Range and Value for Money",
   "25_bolt_instruction_wrench_assembly": "Assembly Instructions and Tools",
   "4_wheel_caster_carpet_roller": "Wheel and Caster Performance on Carpets",
   "26_leather_fabric_quality_color": "Leather Quality, Fabric, and Color Options",
   "13_adjustment_lever_adjustability_comfortable": "Lever Adjustments and Comfort",
   "42_assemble_comfortable_aspect_quality": "Assembly, Comfort, and Quality Aspects",
   "5_home_comfortable_assemble_quality": "Home Chair Comfort and Quality",
   "23_gaming_session_edition_comfortable": "Gaming Edition Comfort",
   "18_hour_comfortable_desk_use": "Comfort for Long Desk Hours",
   "17_quality_comfortable_assemble_sturdiness": "Quality, Comfort, Assembly, and Sturdiness",
   "7_quality_material_value_sturdy": "Material Quality and Sturdiness",
   "12_month_hour_comfortable_assemble": "Monthly Comfort and Assembly",
   "31_aeron_jessica_mirra_redesign": "Aeron and Mirra Chair Redesigns",
   "29_packaging_delivery_damage_assemble": "Packaging, Delivery, and Damage Issues",
   "24_support_comfortable_assemble_recommend": "Support, Comfort, and Recommendations",
   "15_super_comfy_comfort_comfy_comfortablevery": "Superior Comfort and Comfiness",
   "28_star_give_star_reason_star_love": "Star Ratings and Reasons for Love",
   "8_adjustable_comfortable_armrest_assemble": "Adjustable Armrests and Comfort",
   "0_comfortable_assemble_sturdy_stylish": "Comfort, Style, and Sturdiness",
   "14_assembly_instruction_assembly_instruction_assemble": "Assembly Instructions and Process",
   "19_tilt_recline_lock_function": "Tilt, Recline, and Lock Features",
   "20_squeak_squeaky_month_sound": "Squeakiness and Noise Issues",
   "40_arm_comfortable_personal_wheel": "Arm Comfort and Personalization",
   "35_size_perfect_size_chart_comfortable": "Size Fit and Comfort",
   "41_reviewer_consumer_report_read_assemble": "Consumer Reviews and Reports",
   "44_investment_worth_investment_investmentthe_notice": "Investment Worth and Noticeability",
   "48_posture_slouch_healthy_comfortable": "Posture Support and Health",
   "10_color_comfortable_blue_color_bright": "Color Options and Comfort",
   "21_gift_christmas_christmas_gift_christmas_present": "Ideal as Christmas Gifts",
   "46_perfection_glove_fitgreat_comfortable": "Perfect Fit and Comfort",
   "38_carpet_wheel_hardwood_floor_roller": "Performance on Carpet and Hardwood",
   "27_comfortable_solution_flexible_work": "Comfortable Solutions for Flexible Work",
   "34_design_modern_sleek_superior": "Modern and Sleek Design",
   "39_comfortable_long_duration_stretch_composer": "Long Duration Comfort and Stretch",
   "33_month_long_term_comfortable_daily": "Long-term Daily Comfort",
   "36_para_bien_armar_excelente": "Excellent Assembly Experience",
   "47_covid_pandemic_office_coronavirus": "COVID Pandemic and Office Adaptations",
   "43_school_virtual_college_student_online_class": "Suitability for School and Online Classes",
   "37_home_comfortable_chairgetting_pricework": "Home Comfort and Price-to-Work Ratio",
   "45_chaise_qualité_confortable_skin": "Quality and Skin Comfort"}

# %%
df_topics = pd.DataFrame(list(dict.items()), columns=['Topic Name', 'Topic Label'])

# %%
df_topics
# Out:
#                                            Topic Name  \
# 0                  -1_support_comfortable_hour_lumbar
# 1         6_customer_service_customer_service_company
# 2                    2_support_lumbar_adjustable_mesh
# 3               16_cylinder_part_replacement_warranty
# 4                       11_desk_height_assemble_table
# 5                    1_lumbar_support_sit_comfortable
# 6           22_comfortable_assemble_sturdy_ajustments
# 7                  9_cushion_pillow_head_rest_support
# 8                    3_height_size_comfortable_petite
# 9                  32_mesh_breathable_material_fabric
# 10                         30_sale_range_value_dollar
# 11                25_bolt_instruction_wrench_assembly
# 12                       4_wheel_caster_carpet_roller
# 13                    26_leather_fabric_quality_color
# 14      13_adjustment_lever_adjustability_comfortable
# 15             42_assemble_comfortable_aspect_quality
# 16                5_home_comfortable_assemble_quality
# 17              23_gaming_session_edition_comfortable
# 18                       18_hour_comfortable_desk_use
# 19         17_quality_comfortable_assemble_sturdiness
# 20                    7_quality_material_value_sturdy
# 21                 12_month_hour_comfortable_assemble
# 22                    31_aeron_jessica_mirra_redesign
# 23              29_packaging_delivery_damage_assemble
# 24          24_support_comfortable_assemble_recommend
# 25       15_super_comfy_comfort_comfy_comfortablevery
# 26                 28_star_give_star_reason_star_love
# 27          8_adjustable_comfortable_armrest_assemble
# 28              0_comfortable_assemble_sturdy_stylish
# 29  14_assembly_instruction_assembly_instruction_a...
# 30                      19_tilt_recline_lock_function
# 31                      20_squeak_squeaky_month_sound
# 32                  40_arm_comfortable_personal_wheel
# 33             35_size_perfect_size_chart_comfortable
# 34          41_reviewer_consumer_report_read_assemble
# 35  44_investment_worth_investment_investmentthe_n...
# 36              48_posture_slouch_healthy_comfortable
# 37             10_color_comfortable_blue_color_bright
# 38  21_gift_christmas_christmas_gift_christmas_pre...
# 39           46_perfection_glove_fitgreat_comfortable
# 40              38_carpet_wheel_hardwood_floor_roller
# 41              27_comfortable_solution_flexible_work
# 42                    34_design_modern_sleek_superior
# 43      39_comfortable_long_duration_stretch_composer
# 44               33_month_long_term_comfortable_daily
# 45                       36_para_bien_armar_excelente
# 46               47_covid_pandemic_office_coronavirus
# 47     43_school_virtual_college_student_online_class
# 48         37_home_comfortable_chairgetting_pricework
# 49                 45_chaise_qualité_confortable_skin
#
#                                        Topic Label
# 0            Lumbar Support and Comfort Over Hours
# 1         Customer Service and Company Interaction
# 2        Adjustable Lumbar Support and Mesh Design
# 3          Cylinder Parts and Replacement Warranty
# 4      Assembly Ease and Desk Height Compatibility
# 5                           Lumbar Support Comfort
# 6         Comfort, Sturdiness, and Adjustment Ease
# 7                  Cushioning and Headrest Support
# 8   Comfort for Petite Sizes and Height Adjustment
# 9                         Breathable Mesh Material
# 10                  Sale Range and Value for Money
# 11                 Assembly Instructions and Tools
# 12         Wheel and Caster Performance on Carpets
# 13      Leather Quality, Fabric, and Color Options
# 14                   Lever Adjustments and Comfort
# 15          Assembly, Comfort, and Quality Aspects
# 16                  Home Chair Comfort and Quality
# 17                          Gaming Edition Comfort
# 18                     Comfort for Long Desk Hours
# 19      Quality, Comfort, Assembly, and Sturdiness
# 20                 Material Quality and Sturdiness
# 21                    Monthly Comfort and Assembly
# 22                 Aeron and Mirra Chair Redesigns
# 23          Packaging, Delivery, and Damage Issues
# 24           Support, Comfort, and Recommendations
# 25                  Superior Comfort and Comfiness
# 26               Star Ratings and Reasons for Love
# 27                 Adjustable Armrests and Comfort
# 28                  Comfort, Style, and Sturdiness
# 29               Assembly Instructions and Process
# 30                Tilt, Recline, and Lock Features
# 31                    Squeakiness and Noise Issues
# 32                 Arm Comfort and Personalization
# 33                            Size Fit and Comfort
# 34                    Consumer Reviews and Reports
# 35              Investment Worth and Noticeability
# 36                      Posture Support and Health
# 37                       Color Options and Comfort
# 38                        Ideal as Christmas Gifts
# 39                         Perfect Fit and Comfort
# 40              Performance on Carpet and Hardwood
# 41         Comfortable Solutions for Flexible Work
# 42                         Modern and Sleek Design
# 43               Long Duration Comfort and Stretch
# 44                         Long-term Daily Comfort
# 45                   Excellent Assembly Experience
# 46           COVID Pandemic and Office Adaptations
# 47       Suitability for School and Online Classes
# 48            Home Comfort and Price-to-Work Ratio
# 49                        Quality and Skin Comfort

# %%
import pandas as pd
import matplotlib.pyplot as plt

import csv
df = pd.read_csv("pivoted_review_data.csv")
df
# Out:
#     YearMonth  Adjustable Lumbar Support and Mesh Design  \
# 0     2006-03                                        NaN
# 1     2007-04                                        NaN
# 2     2007-06                                        NaN
# 3     2007-12                                        NaN
# 4     2008-01                                        NaN
# ..        ...                                        ...
# 165   2023-08                                   3.074295
# 166   2023-09                                   3.721489
# 167   2023-10                                   4.120267
# 168   2023-11                                   2.374670
# 169   2023-12                                        NaN
#
#      Aeron and Mirra Chair Redesigns  Arm Comfort and Personalization  \
# 0                                NaN                              NaN
# 1                                NaN                              NaN
# 2                                NaN                              NaN
# 3                                NaN                              NaN
# 4                                NaN                              NaN
# ..                               ...                              ...
# 165                              NaN                         0.170794
# 166                              NaN                              NaN
# 167                              NaN                         0.111359
# 168                              NaN                              NaN
# 169                              NaN                              NaN
#
#      Assembly and Instructions  Assembly, Comfort, and Quality Aspects  \
# 0                          NaN                                     NaN
# 1                          NaN                                     NaN
# 2                          NaN                                     NaN
# 3                          NaN                                     NaN
# 4                          NaN                                     NaN
# ..                         ...                                     ...
# 165                   5.038429                                0.170794
# 166                   4.681873                                0.120048
# 167                   4.231626                                0.222717
# 168                   2.902375                                     NaN
# 169                        NaN                                     NaN
#
#      Color Options and Comfort  Comfort and Adjustability  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ..                         ...                        ...
# 165                   0.512383                  10.418446
# 166                   0.840336                  15.846339
# 167                   0.445434                  11.247216
# 168                   1.055409                  15.567282
# 169                        NaN                  27.272727
#
#      Comfort for Petite Sizes and Height Adjustment  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 165                                        1.964133
# 166                                        2.641056
# 167                                        3.118040
# 168                                        0.263852
# 169                                             NaN
#
#      Comfortable Solutions for Flexible Work  ...  Long-term Daily Comfort  \
# 0                                        NaN  ...                      NaN
# 1                                        NaN  ...                      NaN
# 2                                        NaN  ...                      NaN
# 3                                        NaN  ...                      NaN
# 4                                        NaN  ...                      NaN
# ..                                       ...  ...                      ...
# 165                                 0.853971  ...                 0.426985
# 166                                 0.360144  ...                 0.360144
# 167                                 0.556793  ...                 0.445434
# 168                                 0.791557  ...                 1.055409
# 169                                 9.090909  ...                      NaN
#
#      Lumbar Support and Comfort  Material and Design Quality  \
# 0                    100.000000                          NaN
# 1                    100.000000                          NaN
# 2                     50.000000                          NaN
# 3                    100.000000                          NaN
# 4                    100.000000                          NaN
# ..                          ...                          ...
# 165                   54.568745                     6.660974
# 166                   48.619448                     4.921969
# 167                   53.006682                     4.565702
# 168                   51.451187                     6.068602
# 169                   36.363636                     9.090909
#
#      Monthly Comfort and Assembly  Size Fit and Comfort  \
# 0                             NaN                   NaN
# 1                             NaN                   NaN
# 2                             NaN                   NaN
# 3                             NaN                   NaN
# 4                             NaN                   NaN
# ..                            ...                   ...
# 165                      0.683177              0.341588
# 166                      1.560624              0.240096
# 167                      0.890869              0.222717
# 168                      1.319261                   NaN
# 169                           NaN                   NaN
#
#      Squeakiness and Noise Issues  Superior Comfort and Comfiness  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
# 3                             NaN                             NaN
# 4                             NaN                             NaN
# ..                            ...                             ...
# 165                      0.512383                        1.366354
# 166                      0.600240                        1.080432
# 167                      0.556793                        0.334076
# 168                      0.791557                        1.055409
# 169                           NaN                             NaN
#
#      Tilt, Recline, and Lock Features  Use Case Specific Comfort  \
# 0                                 NaN                        NaN
# 1                                 NaN                        NaN
# 2                                 NaN                        NaN
# 3                                 NaN                        NaN
# 4                                 NaN                        NaN
# ..                                ...                        ...
# 165                          0.341588                   3.159693
# 166                          0.240096                   3.841537
# 167                          0.556793                   2.449889
# 168                          0.527704                   3.430079
# 169                               NaN                   9.090909
#
#      Wheel and Surface Compatibility
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ..                               ...
# 165                         2.134927
# 166                         2.160864
# 167                         4.565702
# 168                         3.693931
# 169                              NaN
#
# [170 rows x 25 columns]
# Warning: Total number of columns (25) exceeds max_columns (20) limiting to first (20) columns.

# %%
year = df.iloc[74:]
year
# Out:
#     YearMonth  Adjustable Lumbar Support and Mesh Design  \
# 74    2016-01                                   2.777778
# 75    2016-02                                   2.777778
# 76    2016-03                                        NaN
# 77    2016-04                                   1.886792
# 78    2016-05                                        NaN
# ..        ...                                        ...
# 165   2023-08                                   3.074295
# 166   2023-09                                   3.721489
# 167   2023-10                                   4.120267
# 168   2023-11                                   2.374670
# 169   2023-12                                        NaN
#
#      Aeron and Mirra Chair Redesigns  Arm Comfort and Personalization  \
# 74                               NaN                         0.925926
# 75                               NaN                              NaN
# 76                          3.333333                              NaN
# 77                               NaN                              NaN
# 78                               NaN                         3.333333
# ..                               ...                              ...
# 165                              NaN                         0.170794
# 166                              NaN                              NaN
# 167                              NaN                         0.111359
# 168                              NaN                              NaN
# 169                              NaN                              NaN
#
#      Assembly and Instructions  Assembly, Comfort, and Quality Aspects  \
# 74                    3.703704                                     NaN
# 75                         NaN                                     NaN
# 76                    6.666667                                     NaN
# 77                    1.886792                                     NaN
# 78                         NaN                                     NaN
# ..                         ...                                     ...
# 165                   5.038429                                0.170794
# 166                   4.681873                                0.120048
# 167                   4.231626                                0.222717
# 168                   2.902375                                     NaN
# 169                        NaN                                     NaN
#
#      Color Options and Comfort  Comfort and Adjustability  \
# 74                    1.851852                  25.000000
# 75                    5.555556                  16.666667
# 76                         NaN                   3.333333
# 77                    1.886792                  20.754717
# 78                    6.666667                  30.000000
# ..                         ...                        ...
# 165                   0.512383                  10.418446
# 166                   0.840336                  15.846339
# 167                   0.445434                  11.247216
# 168                   1.055409                  15.567282
# 169                        NaN                  27.272727
#
#      Comfort for Petite Sizes and Height Adjustment  \
# 74                                         1.851852
# 75                                         2.777778
# 76                                         3.333333
# 77                                         7.547170
# 78                                              NaN
# ..                                              ...
# 165                                        1.964133
# 166                                        2.641056
# 167                                        3.118040
# 168                                        0.263852
# 169                                             NaN
#
#      Comfortable Solutions for Flexible Work  ...  Long-term Daily Comfort  \
# 74                                       NaN  ...                      NaN
# 75                                       NaN  ...                      NaN
# 76                                       NaN  ...                      NaN
# 77                                       NaN  ...                      NaN
# 78                                  6.666667  ...                      NaN
# ..                                       ...  ...                      ...
# 165                                 0.853971  ...                 0.426985
# 166                                 0.360144  ...                 0.360144
# 167                                 0.556793  ...                 0.445434
# 168                                 0.791557  ...                 1.055409
# 169                                 9.090909  ...                      NaN
#
#      Lumbar Support and Comfort  Material and Design Quality  \
# 74                    44.444444                     6.481481
# 75                    52.777778                     2.777778
# 76                    63.333333                     6.666667
# 77                    54.716981                     3.773585
# 78                    46.666667                          NaN
# ..                          ...                          ...
# 165                   54.568745                     6.660974
# 166                   48.619448                     4.921969
# 167                   53.006682                     4.565702
# 168                   51.451187                     6.068602
# 169                   36.363636                     9.090909
#
#      Monthly Comfort and Assembly  Size Fit and Comfort  \
# 74                            NaN                   NaN
# 75                       5.555556                   NaN
# 76                       3.333333                   NaN
# 77                            NaN                   NaN
# 78                            NaN                   NaN
# ..                            ...                   ...
# 165                      0.683177              0.341588
# 166                      1.560624              0.240096
# 167                      0.890869              0.222717
# 168                      1.319261                   NaN
# 169                           NaN                   NaN
#
#      Squeakiness and Noise Issues  Superior Comfort and Comfiness  \
# 74                            NaN                        1.851852
# 75                            NaN                             NaN
# 76                       3.333333                             NaN
# 77                            NaN                             NaN
# 78                            NaN                             NaN
# ..                            ...                             ...
# 165                      0.512383                        1.366354
# 166                      0.600240                        1.080432
# 167                      0.556793                        0.334076
# 168                      0.791557                        1.055409
# 169                           NaN                             NaN
#
#      Tilt, Recline, and Lock Features  Use Case Specific Comfort  \
# 74                                NaN                   4.629630
# 75                                NaN                   2.777778
# 76                                NaN                   3.333333
# 77                                NaN                   1.886792
# 78                                NaN                        NaN
# ..                                ...                        ...
# 165                          0.341588                   3.159693
# 166                          0.240096                   3.841537
# 167                          0.556793                   2.449889
# 168                          0.527704                   3.430079
# 169                               NaN                   9.090909
#
#      Wheel and Surface Compatibility
# 74                               NaN
# 75                               NaN
# 76                          3.333333
# 77                               NaN
# 78                               NaN
# ..                               ...
# 165                         2.134927
# 166                         2.160864
# 167                         4.565702
# 168                         3.693931
# 169                              NaN
#
# [96 rows x 25 columns]

# %%
exclude_outliner = year.drop('Lumbar Support and Comfort', axis=1)
exclude_outliner
# Out:
#     YearMonth  Adjustable Lumbar Support and Mesh Design  \
# 60    2014-11                                   3.703704
# 61    2014-12                                        NaN
# 62    2015-01                                        NaN
# 63    2015-02                                   4.347826
# 64    2015-03                                   7.692308
# ..        ...                                        ...
# 165   2023-08                                   3.074295
# 166   2023-09                                   3.721489
# 167   2023-10                                   4.120267
# 168   2023-11                                   2.374670
# 169   2023-12                                        NaN
#
#      Aeron and Mirra Chair Redesigns  Arm Comfort and Personalization  \
# 60                          1.851852                              NaN
# 61                         20.000000                              NaN
# 62                               NaN                              NaN
# 63                          4.347826                              NaN
# 64                               NaN                         3.846154
# ..                               ...                              ...
# 165                              NaN                         0.170794
# 166                              NaN                              NaN
# 167                              NaN                         0.111359
# 168                              NaN                              NaN
# 169                              NaN                              NaN
#
#      Assembly and Instructions  Assembly, Comfort, and Quality Aspects  \
# 60                    3.703704                                     NaN
# 61                         NaN                                     NaN
# 62                    5.555556                                     NaN
# 63                    4.347826                                     NaN
# 64                    3.846154                                     NaN
# ..                         ...                                     ...
# 165                   5.038429                                0.170794
# 166                   4.681873                                0.120048
# 167                   4.231626                                0.222717
# 168                   2.902375                                     NaN
# 169                        NaN                                     NaN
#
#      Color Options and Comfort  Comfort and Adjustability  \
# 60                    1.851852                   4.938272
# 61                         NaN                  20.000000
# 62                         NaN                   5.555556
# 63                    4.347826                   8.695652
# 64                    3.846154                  23.076923
# ..                         ...                        ...
# 165                   0.512383                  10.418446
# 166                   0.840336                  15.846339
# 167                   0.445434                  11.247216
# 168                   1.055409                  15.567282
# 169                        NaN                  27.272727
#
#      Comfort for Petite Sizes and Height Adjustment  \
# 60                                         3.086420
# 61                                              NaN
# 62                                              NaN
# 63                                              NaN
# 64                                         3.846154
# ..                                              ...
# 165                                        1.964133
# 166                                        2.641056
# 167                                        3.118040
# 168                                        0.263852
# 169                                             NaN
#
#      Comfortable Solutions for Flexible Work  ...  \
# 60                                       NaN  ...
# 61                                       NaN  ...
# 62                                       NaN  ...
# 63                                       NaN  ...
# 64                                       NaN  ...
# ..                                       ...  ...
# 165                                 0.853971  ...
# 166                                 0.360144  ...
# 167                                 0.556793  ...
# 168                                 0.791557  ...
# 169                                 9.090909  ...
#
#      Long Duration Comfort and Stretch  Long-term Daily Comfort  \
# 60                            1.234568                      NaN
# 61                                 NaN                      NaN
# 62                                 NaN                      NaN
# 63                                 NaN                      NaN
# 64                                 NaN                      NaN
# ..                                 ...                      ...
# 165                           0.170794                 0.426985
# 166                                NaN                 0.360144
# 167                           0.222717                 0.445434
# 168                           0.527704                 1.055409
# 169                                NaN                      NaN
#
#      Material and Design Quality  Monthly Comfort and Assembly  \
# 60                      3.086420                           NaN
# 61                           NaN                           NaN
# 62                     11.111111                      5.555556
# 63                      4.347826                           NaN
# 64                      7.692308                           NaN
# ..                           ...                           ...
# 165                     6.660974                      0.683177
# 166                     4.921969                      1.560624
# 167                     4.565702                      0.890869
# 168                     6.068602                      1.319261
# 169                     9.090909                           NaN
#
#      Size Fit and Comfort  Squeakiness and Noise Issues  \
# 60                    NaN                           NaN
# 61                    NaN                           NaN
# 62                    NaN                           NaN
# 63                    NaN                           NaN
# 64                    NaN                           NaN
# ..                    ...                           ...
# 165              0.341588                      0.512383
# 166              0.240096                      0.600240
# 167              0.222717                      0.556793
# 168                   NaN                      0.791557
# 169                   NaN                           NaN
#
#      Superior Comfort and Comfiness  Tilt, Recline, and Lock Features  \
# 60                         0.617284                          1.234568
# 61                              NaN                               NaN
# 62                              NaN                               NaN
# 63                              NaN                               NaN
# 64                              NaN                               NaN
# ..                              ...                               ...
# 165                        1.366354                          0.341588
# 166                        1.080432                          0.240096
# 167                        0.334076                          0.556793
# 168                        1.055409                          0.527704
# 169                             NaN                               NaN
#
#      Use Case Specific Comfort  Wheel and Surface Compatibility
# 60                    3.086420                         1.234568
# 61                         NaN                              NaN
# 62                         NaN                         5.555556
# 63                         NaN                              NaN
# 64                    3.846154                              NaN
# ..                         ...                              ...
# 165                   3.159693                         2.134927
# 166                   3.841537                         2.160864
# 167                   2.449889                         4.565702
# 168                   3.430079                         3.693931
# 169                   9.090909                              NaN
#
# [110 rows x 24 columns]

# %%
pivot_data_moving_avg = exclude_outliner.rolling(window=3).mean()  # 3-month moving average
pivot_data_moving_avg
# Out:
# <ipython-input-12-3ba73afadf69>:1: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['YearMonth'], dtype='object')
#   pivot_data_moving_avg = exclude_outliner.rolling(window=3).mean()  # 3-month moving average
#      Adjustable Lumbar Support and Mesh Design  \
# 60                                         NaN
# 61                                         NaN
# 62                                         NaN
# 63                                         NaN
# 64                                         NaN
# ..                                         ...
# 165                                   3.729959
# 166                                   4.074397
# 167                                   3.638684
# 168                                   3.405475
# 169                                        NaN
#
#      Aeron and Mirra Chair Redesigns  Arm Comfort and Personalization  \
# 60                               NaN                              NaN
# 61                               NaN                              NaN
# 62                               NaN                              NaN
# 63                               NaN                              NaN
# 64                               NaN                              NaN
# ..                               ...                              ...
# 165                              NaN                         0.161897
# 166                              NaN                              NaN
# 167                              NaN                              NaN
# 168                              NaN                              NaN
# 169                              NaN                              NaN
#
#      Assembly and Instructions  Assembly, Comfort, and Quality Aspects  \
# 60                         NaN                                     NaN
# 61                         NaN                                     NaN
# 62                         NaN                                     NaN
# 63                         NaN                                     NaN
# 64                    4.583178                                     NaN
# ..                         ...                                     ...
# 165                   3.492908                                     NaN
# 166                   3.918527                                     NaN
# 167                   4.650642                                0.171186
# 168                   3.938624                                     NaN
# 169                        NaN                                     NaN
#
#      Color Options and Comfort  Comfort and Adjustability  \
# 60                         NaN                        NaN
# 61                         NaN                        NaN
# 62                         NaN                  10.164609
# 63                         NaN                  11.417069
# 64                         NaN                  12.442710
# ..                         ...                        ...
# 165                   0.576148                  14.501008
# 166                   0.677048                  14.227565
# 167                   0.599384                  12.504000
# 168                   0.780393                  14.220279
# 169                        NaN                  18.029075
#
#      Comfort for Petite Sizes and Height Adjustment  \
# 60                                              NaN
# 61                                              NaN
# 62                                              NaN
# 63                                              NaN
# 64                                              NaN
# ..                                              ...
# 165                                        2.513372
# 166                                        2.258718
# 167                                        2.574410
# 168                                        2.007650
# 169                                             NaN
#
#      Comfortable Solutions for Flexible Work  Cushioning and Headrest Support  \
# 60                                       NaN                              NaN
# 61                                       NaN                              NaN
# 62                                       NaN                              NaN
# 63                                       NaN                              NaN
# 64                                       NaN                              NaN
# ..                                       ...                              ...
# 165                                 0.615765                         2.111974
# 166                                 0.676075                         1.915336
# 167                                 0.590303                         1.703246
# 168                                 0.569498                         1.692656
# 169                                 3.479753                              NaN
#
#      ...  Long Duration Comfort and Stretch  Long-term Daily Comfort  \
# 60   ...                                NaN                      NaN
# 61   ...                                NaN                      NaN
# 62   ...                                NaN                      NaN
# 63   ...                                NaN                      NaN
# 64   ...                                NaN                      NaN
# ..   ...                                ...                      ...
# 165  ...                                NaN                 0.292522
# 166  ...                                NaN                 0.352833
# 167  ...                                NaN                 0.410855
# 168  ...                                NaN                 0.620329
# 169  ...                                NaN                      NaN
#
#      Material and Design Quality  Monthly Comfort and Assembly  \
# 60                           NaN                           NaN
# 61                           NaN                           NaN
# 62                           NaN                           NaN
# 63                           NaN                           NaN
# 64                      7.717082                           NaN
# ..                           ...                           ...
# 165                     5.385502                      1.159609
# 166                     5.353518                      1.381131
# 167                     5.382881                      1.044890
# 168                     5.185424                      1.256918
# 169                     6.575071                           NaN
#
#      Size Fit and Comfort  Squeakiness and Noise Issues  \
# 60                    NaN                           NaN
# 61                    NaN                           NaN
# 62                    NaN                           NaN
# 63                    NaN                           NaN
# 64                    NaN                           NaN
# ..                    ...                           ...
# 165                   NaN                      0.590656
# 166              0.284352                      0.551788
# 167              0.268134                      0.556472
# 168                   NaN                      0.649530
# 169                   NaN                           NaN
#
#      Superior Comfort and Comfiness  Tilt, Recline, and Lock Features  \
# 60                              NaN                               NaN
# 61                              NaN                               NaN
# 62                              NaN                               NaN
# 63                              NaN                               NaN
# 64                              NaN                               NaN
# ..                              ...                               ...
# 165                        1.220930                          0.473988
# 166                        1.222651                          0.374808
# 167                        0.926954                          0.379492
# 168                        0.823306                          0.441531
# 169                             NaN                               NaN
#
#      Use Case Specific Comfort  Wheel and Surface Compatibility
# 60                         NaN                              NaN
# 61                         NaN                              NaN
# 62                         NaN                              NaN
# 63                         NaN                              NaN
# 64                         NaN                              NaN
# ..                         ...                              ...
# 165                   2.312818                         3.188992
# 166                   2.876484                         2.834011
# 167                   3.150373                         2.953831
# 168                   3.240501                         3.473499
# 169                   4.990292                              NaN
#
# [110 rows x 23 columns]

# %%
# Calculate the total reviews per month
total_reviews_per_month = exclude_outliner.groupby('YearMonth').size()
total_reviews_per_month
# Out:
# YearMonth
# 2014-11    1
# 2014-12    1
# 2015-01    1
# 2015-02    1
# 2015-03    1
#           ..
# 2023-08    1
# 2023-09    1
# 2023-10    1
# 2023-11    1
# 2023-12    1
# Length: 110, dtype: int64

# %%
# Pivot the data for plotting
exclude_outliner.pivot(index='YearMonth', columns='Merged_Topics', values='Percentage')

# Plotting
plt.figure(figsize=(15, 8))
pivot_data.plot(kind='area', stacked=True, ax=plt.gca())
plt.title('Percentage of Reviews per Topic Over Time (Monthly Basis)', fontsize=14)
plt.xlabel('Year and Month', fontsize=12)
plt.ylabel('Percentage of Total Reviews', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title='Topics', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Merged_Topics'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-06b4a3ca6a89> in <cell line: 2>()
#       1 # Pivot the data for plotting
# ----> 2 exclude_outliner.pivot(index='YearMonth', columns='Merged_Topics', values='Percentage')
#       3
#       4 # Plotting
#       5 plt.figure(figsize=(15, 8))
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    8565         from pandas.core.reshape.pivot import pivot
#    8566
# -> 8567         return pivot(self, index=index, columns=columns, values=values)
#    8568
#    8569     _shared_docs[
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     523             index_list = [data[idx] for idx in com.convert_to_list_like(index)]
#     524
# --> 525         data_columns = [data[col] for col in columns_listlike]
#     526         index_list.extend(data_columns)
#     527         multiindex = MultiIndex.from_arrays(index_list)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/pivot.py in <listcomp>(.0)
#     523             index_list = [data[idx] for idx in com.convert_to_list_like(index)]
#     524
# --> 525         data_columns = [data[col] for col in columns_listlike]
#     526         index_list.extend(data_columns)
#     527         multiindex = MultiIndex.from_arrays(index_list)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Merged_Topics'
