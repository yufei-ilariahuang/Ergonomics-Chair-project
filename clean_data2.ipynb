# %%
import pandas as pd
import csv
import sys

csv.field_size_limit(sys.maxsize)

df = pd.read_csv("/Users/faye/Library/CloudStorage/OneDrive-NortheasternUniversity/thesis_/my code/final_data_!!! copy.csv")

# %%
df
# Out:
#               country        date  product/price/value productAsin  \
# 0       United States  2023-09-01               359.99  B0C3T865C2
# 1             Germany  2023-10-27               359.99  B0C3T865C2
# 2               Spain  2023-10-24               359.99  B0C3T865C2
# 3      United Kingdom  2023-10-04               359.99  B0C3T865C2
# 4      United Kingdom  2023-09-27               359.99  B0C3T865C2
# ...               ...         ...                  ...         ...
# 36201   United States  2022-08-11               729.99  B09NS55NY1
# 36202   United States  2020-01-24               729.99  B09NS55NY1
# 36203   United States  2020-04-28               729.99  B09NS55NY1
# 36204   United States  2020-11-04               729.99  B09NS55NY1
# 36205   United States  2020-01-27               729.99  B09NS55NY1
#
#        ratingScore                                  reviewCategoryUrl  \
# 0                3  https://www.amazon.com/product-reviews/B0C3T86...
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of               country        date  product/price/value productAsin  \
# 0       United States  2023-09-01               359.99  B0C3T865C2
# 1             Germany  2023-10-27               359.99  B0C3T865C2
# 2               Spain  2023-10-24               359.99  B0C3T865C2
# 3      United Kingdom  2023-10-04               359.99  B0C3T865C2
# 4      United Kingdom  2023-09-27               359.99  B0C3T865C2
# ...               ...         ...                  ...         ...
# 36201   United States  2022-08-11               729.99  B09NS55NY1
# 36202   United States  2020-01-24               729.99  B09NS55NY1
# 36203   United States  2020-04-28               729.99  B09NS55NY1
# 36204   United States  2020-11-04               729.99  B09NS55NY1
# 36205   United States  2020-01-27               729.99  B09NS55NY1
#
#        ratingScore                                  reviewCategoryUrl  \
# ...

# %%
df = df.drop("reviewReaction", axis = 1)

# %%
df
# Out:
#               country        date  product/price/value productAsin  \
# 0       United States  2023-09-01               359.99  B0C3T865C2
# 1             Germany  2023-10-27               359.99  B0C3T865C2
# 2               Spain  2023-10-24               359.99  B0C3T865C2
# 3      United Kingdom  2023-10-04               359.99  B0C3T865C2
# 4      United Kingdom  2023-09-27               359.99  B0C3T865C2
# ...               ...         ...                  ...         ...
# 36201   United States  2022-08-11               729.99  B09NS55NY1
# 36202   United States  2020-01-24               729.99  B09NS55NY1
# 36203   United States  2020-04-28               729.99  B09NS55NY1
# 36204   United States  2020-11-04               729.99  B09NS55NY1
# 36205   United States  2020-01-27               729.99  B09NS55NY1
#
#        ratingScore                                  reviewCategoryUrl  \
# 0                3  https://www.amazon.com/product-reviews/B0C3T86...
# ...

# %%
df[' Review'] = df['reviewTitle'].str.cat(df['reviewDescription'], sep=' ')
df
# Out:
#               country        date  product/price/value productAsin  \
# 0       United States  2023-09-01               359.99  B0C3T865C2
# 1             Germany  2023-10-27               359.99  B0C3T865C2
# 2               Spain  2023-10-24               359.99  B0C3T865C2
# 3      United Kingdom  2023-10-04               359.99  B0C3T865C2
# 4      United Kingdom  2023-09-27               359.99  B0C3T865C2
# ...               ...         ...                  ...         ...
# 36201   United States  2022-08-11               729.99  B09NS55NY1
# 36202   United States  2020-01-24               729.99  B09NS55NY1
# 36203   United States  2020-04-28               729.99  B09NS55NY1
# 36204   United States  2020-11-04               729.99  B09NS55NY1
# 36205   United States  2020-01-27               729.99  B09NS55NY1
#
#        ratingScore                                  reviewCategoryUrl  \
# 0                3  https://www.amazon.com/product-reviews/B0C3T86...
# ...

# %%
df = df.drop("reviewDescription", axis = 1)

# %%
df = df.drop("reviewTitle", axis = 1)

# %%
df
# Out:
#               country        date  product/price/value productAsin  \
# 0       United States  2023-09-01               359.99  B0C3T865C2
# 1             Germany  2023-10-27               359.99  B0C3T865C2
# 2               Spain  2023-10-24               359.99  B0C3T865C2
# 3      United Kingdom  2023-10-04               359.99  B0C3T865C2
# 4      United Kingdom  2023-09-27               359.99  B0C3T865C2
# ...               ...         ...                  ...         ...
# 36201   United States  2022-08-11               729.99  B09NS55NY1
# 36202   United States  2020-01-24               729.99  B09NS55NY1
# 36203   United States  2020-04-28               729.99  B09NS55NY1
# 36204   United States  2020-11-04               729.99  B09NS55NY1
# 36205   United States  2020-01-27               729.99  B09NS55NY1
#
#        ratingScore                                  reviewCategoryUrl  \
# 0                3  https://www.amazon.com/product-reviews/B0C3T86...
# ...

# %%
df = df.rename(columns={'product/price/value': 'price'})

# %%
# Write the updated DataFrame to a new CSV file
df.to_csv('dataCleaned.csv', index=False)

# %%
cell_value1 = df.iloc[0, 5]
cell_value2 = df.iloc[1, 5]
cell_value3 = df.iloc[2, 5]
print(cell_value1, "\n", cell_value2, "\n", cell_value3)
# Out:
# https://www.amazon.com/product-reviews/B0C3T865C2?reviewerType=all_reviews&pageNumber=1&pageSize=10&asin=B0C3T865C2&scope=reviewsAjax1&filterByStar=three_star&sortBy=recent
#  https://www.amazon.com/product-reviews/B0C3T865C2?reviewerType=all_reviews&pageNumber=1&pageSize=10&asin=B0C3T865C2&scope=reviewsAjax1&filterByStar=three_star&sortBy=recent
#  https://www.amazon.com/product-reviews/B0C3T865C2?reviewerType=all_reviews&pageNumber=1&pageSize=10&asin=B0C3T865C2&scope=reviewsAjax1&filterByStar=three_star&sortBy=recent

# %%
df_us = df[df['country'] == 'United States']
df_us
# Out:
#              country        date   price productAsin  ratingScore  \
# 0      United States  2023-09-01  359.99  B0C3T865C2            3
# 9      United States  2023-10-18  229.99  B07BDFW1Y7            2
# 10     United States  2023-10-16  229.99  B07BDFW1Y7            2
# 11     United States  2023-10-12  229.99  B07BDFW1Y7            2
# 12     United States  2023-09-15  229.99  B07BDFW1Y7            2
# ...              ...         ...     ...         ...          ...
# 36201  United States  2022-08-11  729.99  B09NS55NY1            5
# 36202  United States  2020-01-24  729.99  B09NS55NY1            5
# 36203  United States  2020-04-28  729.99  B09NS55NY1            5
# 36204  United States  2020-11-04  729.99  B09NS55NY1            5
# 36205  United States  2020-01-27  729.99  B09NS55NY1            5
#
#                                        reviewCategoryUrl  \
# 0      https://www.amazon.com/product-reviews/B0C3T86...
# ...

# %% [markdown]
# 筛选只是us的数据，从36206 减少到34292

# %%
sentiment = pipeline("sentiment-analysis")
feature_expraction = pipeline("feature-extraction")
classification = pipeline('text-classification')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/faye/Library/CloudStorage/OneDrive-NortheasternUniversity/thesis_/my code/clean_data2.ipynb Cell 17 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/faye/Library/CloudStorage/OneDrive-NortheasternUniversity/thesis_/my%20code/clean_data2.ipynb#X54sZmlsZQ%3D%3D?line=0'>1</a> sentiment = pipeline("sentiment-analysis")
#       <a href='vscode-notebook-cell:/Users/faye/Library/CloudStorage/OneDrive-NortheasternUniversity/thesis_/my%20code/clean_data2.ipynb#X54sZmlsZQ%3D%3D?line=1'>2</a> feature_expraction = pipeline("feature-extraction")
#       <a href='vscode-notebook-cell:/Users/faye/Library/CloudStorage/OneDrive-NortheasternUniversity/thesis_/my%20code/clean_data2.ipynb#X54sZmlsZQ%3D%3D?line=2'>3</a> classification = pipeline('text-classification')
#
# NameError: name 'pipeline' is not defined

# %%
sentiment(cell_value1)
# Out:
# [{'label': 'NEGATIVE', 'score': 0.8855617046356201}]

# %%
import statistics

feature_expraction(cell_value1)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !pip install tree
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 1.6 MB/s eta 0:00:00
# ...
#   Created wheel for tree: filename=Tree-0.2.4-py3-none-any.whl size=7860 sha256=9821807179c46728c8ffd887572682b18cb6bc3dcf79edaa35dc28c13c990aad
#   Stored in directory: /root/.cache/pip/wheels/06/1e/8c/73b3a97f37991dc90603631567511071513ee3c6d819393232
# Successfully built tree
# ...

# %%
# !ls
# Out:
#  dataCleaned.csv   drive  'final_data_!!!.csv'	 sample_data

# %%
classification(cell_value1)
# Out:
# [{'label': 'NEGATIVE', 'score': 0.8855617046356201}]

# %%
df_us.to_csv('dataCleaned.csv', index=False)
